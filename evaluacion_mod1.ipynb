# %%
class TiendaOnline:    #Clase
    
    def __init__(self):  #Constructor

            #Atributos
        self.inventario = []       #Lista para el inventario vacia      
        self.ventas_totales = 0.0    #Para almacenar las ventas totales(float)

                 #Metodos
    #Agregar producto, si existe se suma, si no existe se agrega
    def agregar_producto(self, nombre, precio, cantidad):
        for producto in self.inventario:
            if producto["nombre"] == nombre:
                producto["cantidad"] += cantidad
                return   #return para que no se ejecute lo de abajo (si se ejecuta el if)
        #Se ejecuta si no entra en el if    
        self.inventario.append({"nombre": nombre, "precio": precio, "cantidad": cantidad})

    #Ver el inventario
    def ver_inventario(self):
        for producto in self.inventario:                 
            print(f" Nombre: {producto["nombre"]}, Precio: {producto["precio"]}, Cantidad: {producto["cantidad"]}")

    #Buscar por nombre del producto
    def buscar_producto(self, nombre):
        for producto in self.inventario:
            if producto["nombre"] == nombre:  
                print(f" Nombre: {producto["nombre"]}, Precio: {producto["precio"]}, Cantidad: {producto["cantidad"]}")
                return            
        print("El producto no existe en el inventario")

    #Actualizar las cantidades de producto que tengamos en el stock
    def actualizar_stock(self, nombre, cantidad):
        for producto in self.inventario:
            if producto["nombre"] == nombre:
                producto["cantidad"] += cantidad
                return  #Si entra en el if, termina la ejecucion
        print("El producto no esta en el inventario")  #Si no entra en el if

    #Eliminar producto por nombre
    def eliminar_producto(self, nombre):
        for producto in self.inventario:
            if producto["nombre"] == nombre:
                self.inventario.remove(producto)
                return #Finaliza aqui
        print("No se puede eliminar, no esta en el inventario") #No entra al if, ejecuta el print
        
    #Calcular el total del inventario
    def calcular_valor_inventario(self):
        total = 0     #Para que almacene cada iteracion
        for producto in self.inventario:
            total += (producto["cantidad"] * producto["precio"])
        print(f"El valor total del stock es {total}€")

# %%
tienda = TiendaOnline()

# %%
tienda.agregar_producto("fresa", 2.50, 30)

# %%
tienda.agregar_producto("pera", 1.20, 40)

# %%
tienda.agregar_producto("fresa", 2.50, 20)

# %%
tienda.ver_inventario()
# Out:
#  Nombre: fresa, Precio: 2.5, Cantidad: 50
#  Nombre: pera, Precio: 1.2, Cantidad: 40

# %%
tienda.buscar_producto("fresa")
# Out:
#  Nombre: fresa, Precio: 2.5, Cantidad: 50

# %%
tienda.actualizar_stock("fresa", 5)

# %%
tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'fresa', 'precio': 2.5, 'cantidad': 55},
#   {'nombre': 'pera', 'precio': 1.2, 'cantidad': 40}],
#  'ventas_totales': 0.0}

# %%
tienda.actualizar_stock("uva", 10)
# Out:
# El producto no esta en el inventario

# %%
tienda.agregar_producto("uva", 2, 20)

# %%
tienda.ver_inventario()
# Out:
#  Nombre: fresa, Precio: 2.5, Cantidad: 55
#  Nombre: pera, Precio: 1.2, Cantidad: 40
#  Nombre: uva, Precio: 2, Cantidad: 20

# %%
tienda.agregar_producto("uva", 2, 5)

# %%
tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'fresa', 'precio': 2.5, 'cantidad': 55},
#   {'nombre': 'pera', 'precio': 1.2, 'cantidad': 40},
#   {'nombre': 'uva', 'precio': 2, 'cantidad': 25}],
#  'ventas_totales': 0.0}

# %%
tienda.ver_inventario()
# Out:
#  Nombre: fresa, Precio: 2.5, Cantidad: 55
#  Nombre: pera, Precio: 1.2, Cantidad: 40
#  Nombre: uva, Precio: 2, Cantidad: 25

# %%
tienda.agregar_producto("pera", 1.20, 5)

# %%
tienda.actualizar_stock("uva", 15)

# %%
tienda.ver_inventario()
# Out:
#  Nombre: fresa, Precio: 2.5, Cantidad: 55
#  Nombre: pera, Precio: 1.2, Cantidad: 45
#  Nombre: uva, Precio: 2, Cantidad: 40

# %%
tienda.buscar_producto("uva")
# Out:
#  Nombre: uva, Precio: 2, Cantidad: 40

# %%
tienda.buscar_producto("fresa")
# Out:
#  Nombre: fresa, Precio: 2.5, Cantidad: 55

# %%
tienda.buscar_producto("pera")
# Out:
#  Nombre: pera, Precio: 1.2, Cantidad: 45

# %%
tienda.buscar_producto("sandia")
# Out:
# El producto no existe en el inventario

# %%
tienda.actualizar_stock("fresa", -5)

# %%
tienda.ver_inventario()
# Out:
#  Nombre: fresa, Precio: 2.5, Cantidad: 50
#  Nombre: pera, Precio: 1.2, Cantidad: 45
#  Nombre: uva, Precio: 2, Cantidad: 40

# %%
tienda.eliminar_producto("pera")

# %%
tienda.__dict__
# Out:
# {'inventario': [{'nombre': 'fresa', 'precio': 2.5, 'cantidad': 50},
#   {'nombre': 'uva', 'precio': 2, 'cantidad': 40}],
#  'ventas_totales': 0.0}

# %%
tienda.ver_inventario()
# Out:
#  Nombre: fresa, Precio: 2.5, Cantidad: 50
#  Nombre: uva, Precio: 2, Cantidad: 40

# %%
tienda.eliminar_producto("pera")
# Out:
# No se puede eliminar, no esta en el inventario

# %%
tienda.buscar_producto("pera")
# Out:
# El producto no existe en el inventario

# %%
tienda.actualizar_stock("pera", 20)
# Out:
# El producto no esta en el inventario

# %%
tienda.calcular_valor_inventario()
# Out:
# El valor total del stock es 205.0€

# %%
tienda.agregar_producto("sandia", 3, 30)

# %%
tienda.buscar_producto("sandia")
# Out:
#  Nombre: sandia, Precio: 3, Cantidad: 30

# %%
tienda.ver_inventario()
# Out:
#  Nombre: fresa, Precio: 2.5, Cantidad: 50
#  Nombre: uva, Precio: 2, Cantidad: 40
#  Nombre: sandia, Precio: 3, Cantidad: 30

# %%
tienda.calcular_valor_inventario()
# Out:
# El valor total del stock es 295.0€
